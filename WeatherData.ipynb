# %%
# Dependencies and setup
import pandas as pd
import numpy as np
import requests
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Import unemployment rate csv file, create DataFrame, and set index to Area Type
unemployment_data = Path('Resources/Local_Area_Unemployment_Statistics__LAUS___Annual_Average.csv')
unemployment_df = pd.read_csv(unemployment_data)
unemployment_df = unemployment_df.set_index('Area Type')
unemployment_df

# %%
# Filter Area Type to only include County and State data and reduce columns
area_type_df = unemployment_df.loc[['State','County'],
                                   ['Area Name', 'Year', 'Labor Force', 'Employment', 'Unemployment','Unemployment Rate']]
area_type_df

# Group by Year and calculate averages
year_grouped = area_type_df.groupby(['Year', 'Area Name']).mean()
year_grouped

# Reduce to only 2017-2022
recent = year_grouped.loc[[2017, 2018, 2019, 2020, 2021, 2022]]
recent
# Out:
#                        Labor Force  Employment  Unemployment  \
# Year Area Name
# 2017 Alameda County       838200.0    807100.0       31100.0
#      Alpine County           550.0       510.0          30.0
#      Amador County         14690.0     13960.0         740.0
#      Butte County         102000.0     96100.0        5900.0
#      Calaveras County      21020.0     20010.0        1000.0
# ...                            ...         ...           ...
# 2022 Tulare County        207500.0    190500.0       16900.0
#      Tuolumne County       19880.0     18990.0         890.0
#      Ventura County       413600.0    398400.0       15200.0
#      Yolo County          109000.0    104600.0        4400.0
#      Yuba County           31600.0     29900.0        1700.0
#
#                        Unemployment Rate
# Year Area Name
# 2017 Alameda County                  3.7
#      Alpine County                   6.2
#      Amador County                   5.0
#      Butte County                    5.8
#      Calaveras County                4.8
# ...                                  ...
# 2022 Tulare County                   8.2
#      Tuolumne County                 4.5
#      Ventura County                  3.7
#      Yolo County                     4.0
#      Yuba County                     5.5
#
# [354 rows x 4 columns]

# %%
# Out:
#                  Area Name  Year  Labor Force  Employment  Unemployment  \
# Area Type
# State           California  1990     15141700    14267900        873800
# State           California  1991     15130500    13949700       1180800
# State           California  1992     15303900    13871400       1432500
# State           California  1993     15262300    13809100       1453200
# State           California  1994     15266400    13943500       1322800
# ...                    ...   ...          ...         ...           ...
# County       Tulare County  2022       207500      190500         16900
# County     Tuolumne County  2022        19880       18990           890
# County      Ventura County  2022       413600      398400         15200
# County         Yolo County  2022       109000      104600          4400
# County         Yuba County  2022        31600       29900          1700
#
#            Unemployment Rate
# Area Type
# State                    5.8
# State                    7.8
# State                    9.4
# State                    9.5
# State                    8.7
# ...                      ...
# County                   8.2
# County                   4.5
# County                   3.7
# County                   4.0
# County                   5.5
#
# [1947 rows x 6 columns]

# %%
weather_data = Path('20172022precipitation.csv')
weather_df = pd.read_csv(weather_data)
#weather_df.set_index('Name', inplace=True)
weather_df = weather_df.set_index('Name')
#weather_df = weather_df.loc
year_grouped = weather_df.groupby(['Year', 'Name'])
weather_df
# Out:
#                       ID       State  Value  Rank  \
# Name
# Alameda County    CA-001  California  24.97   110
# Alpine County     CA-003  California  64.24   127
# Amador County     CA-005  California  55.94   124
# Butte County      CA-007  California  56.41   107
# Calaveras County  CA-009  California  51.55   122
# ...                  ...         ...    ...   ...
# Tulare County     CA-107  California  12.31    12
# Tuolumne County   CA-109  California  29.48    24
# Ventura County    CA-111  California   9.95    13
# Yolo County       CA-113  California  11.49    12
# Yuba County       CA-115  California  23.37    11
#
#                   Anomaly (1901-2000 base period)  1901-2000 Mean  Year
# Name
# Alameda County                               6.22           18.75  2017
# Alpine County                               28.10           36.14  2017
# Amador County                               20.71           35.23  2017
# Butte County                                12.00           44.41  2017
# Calaveras County                            17.28           34.27  2017
# ...                                           ...             ...   ...
# Tulare County                               -9.53           21.84  2022
# Tuolumne County                            -11.36           40.84  2022
# Ventura County                             -10.46           20.41  2022
# Yolo County                                 -8.52           20.01  2022
# Yuba County                                -14.36           37.73  2022
#
# [348 rows x 7 columns]

# %%
# Import age csv file and create DataFrame
age_data = Path('Resources/experiencing_homelessness_age_demographics.csv')
age_df = pd.read_csv(age_data)
age_df
# Out:
#       CALENDAR_YEAR  COC_ID                    COC_NAME AGE_GROUP_PUBLIC  \
# 0              2017     All                  California            18-24
# 1              2017     All                  California            25-34
# 2              2017     All                  California            35-44
# 3              2017     All                  California            45-54
# 4              2017     All                  California            55-64
# ...             ...     ...                         ...              ...
# 2136           2022  CA-614  San Luis Obispo County CoC            45-54
# 2137           2022  CA-614  San Luis Obispo County CoC            55-64
# 2138           2022  CA-614  San Luis Obispo County CoC              65+
# 2139           2022  CA-614  San Luis Obispo County CoC         Under 18
# 2140           2022  CA-614  San Luis Obispo County CoC          Unknown
#
#      EXPERIENCING_HOMELESSNESS_CNT
# 0                            15862
# 1                            28339
# 2                            25556
# 3                            27441
# 4                            23220
# ...                            ...
# 2136                           389
# 2137                           360
# 2138                           174
# 2139                           742
# 2140                            62
#
# [2141 rows x 5 columns]

# %%
# Create clean DataFrame by dropping rows with '*' in count column
clean_age_df = age_df.loc[age_df['EXPERIENCING_HOMELESSNESS_CNT']!='*']
clean_age_df
# Out:
#       CALENDAR_YEAR  COC_ID                    COC_NAME AGE_GROUP_PUBLIC  \
# 0              2017     All                  California            18-24
# 1              2017     All                  California            25-34
# 2              2017     All                  California            35-44
# 3              2017     All                  California            45-54
# 4              2017     All                  California            55-64
# ...             ...     ...                         ...              ...
# 2136           2022  CA-614  San Luis Obispo County CoC            45-54
# 2137           2022  CA-614  San Luis Obispo County CoC            55-64
# 2138           2022  CA-614  San Luis Obispo County CoC              65+
# 2139           2022  CA-614  San Luis Obispo County CoC         Under 18
# 2140           2022  CA-614  San Luis Obispo County CoC          Unknown
#
#      EXPERIENCING_HOMELESSNESS_CNT
# 0                            15862
# 1                            28339
# 2                            25556
# 3                            27441
# 4                            23220
# ...                            ...
# 2136                           389
# 2137                           360
# 2138                           174
# 2139                           742
# 2140                            62
#
# [2036 rows x 5 columns]

# %%
# Import ethnicity csv file and create DataFrame
ethnicity_data = Path('resources/experiencing_homelessness_ethnicity_demographics.csv')
ethnicity_df = pd.read_csv(ethnicity_data)
ethnicity_df
# Out:
#      CALENDAR_YEAR  COC_ID                    COC_NAME            ETHNICITY  \
# 0             2017     All                  California      Hispanic/Latinx
# 1             2017     All                  California  Not Hispanic/Latinx
# 2             2017     All                  California              Unknown
# 3             2017  CA-500      Santa Clara County CoC      Hispanic/Latinx
# 4             2017  CA-500      Santa Clara County CoC  Not Hispanic/Latinx
# ..             ...     ...                         ...                  ...
# 782           2022  CA-613         Imperial County CoC  Not Hispanic/Latinx
# 783           2022  CA-613         Imperial County CoC              Unknown
# 784           2022  CA-614  San Luis Obispo County CoC      Hispanic/Latinx
# 785           2022  CA-614  San Luis Obispo County CoC  Not Hispanic/Latinx
# 786           2022  CA-614  San Luis Obispo County CoC              Unknown
#
#     EXPERIENCING_HOMELESSNESS
# 0                       59663
# 1                      118412
# 2                        3796
# 3                        5010
# 4                        5005
# ..                        ...
# 782                       248
# 783                        74
# 784                       994
# 785                      1722
# 786                       144
#
# [787 rows x 5 columns]

# %%
# Import gender csv file and create DataFrame
gender_data = Path('resources/experiencing_homelessness_gender_demographics.csv')
gender_df = pd.read_csv(gender_data)
gender_df
# Out:
#       CALENDAR_YEAR  COC_ID                    COC_NAME               GENDER  \
# 0              2017     All                  California               Female
# 1              2017     All                  California                 Male
# 2              2017     All                  California  Non-Singular Gender
# 3              2017     All                  California   Questioning Gender
# 4              2017     All                  California          Transgender
# ...             ...     ...                         ...                  ...
# 1229           2022  CA-614  San Luis Obispo County CoC               Female
# 1230           2022  CA-614  San Luis Obispo County CoC                 Male
# 1231           2022  CA-614  San Luis Obispo County CoC  Non-Singular Gender
# 1232           2022  CA-614  San Luis Obispo County CoC          Transgender
# 1233           2022  CA-614  San Luis Obispo County CoC              Unknown
#
#      EXPERIENCING_HOMELESSNESS_CNT
# 0                            78453
# 1                           101150
# 2                              137
# 3                                *
# 4                              667
# ...                            ...
# 1229                          1279
# 1230                          1556
# 1231                             *
# 1232                             *
# 1233                            14
#
# [1234 rows x 5 columns]

# %%
# Import race csv file and create DataFrame
race_data = Path('resources/experiencing_homelessness_race_demographics.csv')
race_df = pd.read_csv(race_data)
race_df
# Out:
#       CALENDAR_YEAR  COC_ID                    COC_NAME  \
# 0              2017     All                  California
# 1              2017     All                  California
# 2              2017     All                  California
# 3              2017     All                  California
# 4              2017     All                  California
# ...             ...     ...                         ...
# 1840           2022  CA-614  San Luis Obispo County CoC
# 1841           2022  CA-614  San Luis Obispo County CoC
# 1842           2022  CA-614  San Luis Obispo County CoC
# 1843           2022  CA-614  San Luis Obispo County CoC
# 1844           2022  CA-614  San Luis Obispo County CoC
#
#                                                RACE EXPERIENCING_HOMELESSNESS
# 0     American Indian, Alaska Native, or Indigenous                      5588
# 1                           Asian or Asian American                      2951
# 2               Black, African American, or African                     57413
# 3                                    Multiple Races                      8919
# 4               Native Hawaiian or Pacific Islander                      2547
# ...                                             ...                       ...
# 1840            Black, African American, or African                       144
# 1841                                 Multiple Races                       170
# 1842            Native Hawaiian or Pacific Islander                        27
# 1843                                        Unknown                       166
# 1844                                          White                      2244
#
# [1845 rows x 5 columns]
